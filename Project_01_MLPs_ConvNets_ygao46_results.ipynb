# %% [markdown]
# # ECE 763 Project 01: Training Multi-Layer Perceptrons and Convoluational Neural Networks on CIFAR10

# %% [markdown]
# Objectives:
#
# - To get hands-on experiences on working with images (CIFAR10) and neural networks by implementing multi-layer perceptrons (MLPs) and convolutional neural networks (ConvNets).
# - To test different regularization strategies to get the best performance out of your models.
# - To investigate the limitations of using MLPs in this task, compared with ConvNets.
# - To investigate the potential risk of fitting noise of both MLPs and ConvNets.

# %% [markdown]
# ### What to Do?
#
# * Assume you have installed the ece763 environment. Run this notebook with that environment.
# * Write your code and text for all TODOs as shown by:
#
# ```python
#     # TODO: ??? points - descriptions of what to do
#     raise NotImplementedError # comment it out after you write your code
# ```

# %% [markdown]
# ### How to submit your solutions
#
# * Add your NCSU ID as the postfix of the notebook filename, e.g., `Project_01_MLPs_ConvNets_twu19.ipynb`
# * Submit two versions of your notebook, one is fully executed with all outputs (`Project_01_MLPs_ConvNets_twu19_results.ipynb`), and the other with all outputs cleared (`Project_01_MLPs_ConvNets_twu19_empty.ipynb`). We will re-run the latter and expect the results will be exactly the same as those in the former.
#
# * Late policy:  5 free late days (counted using 0.5 unit, <=6 hours as 0.5 late day, otherwise 1 later day) in total – use them in your ways; Afterwards, 25% off per day late; Not accepted after 3 late days per HW and Project. Not applicable to the final project.
# * Important Note: We will NOT accept any replacement of submission after deadline, even if you can show the time stamp of the replacement is earlier than the deadline. So, please double-check if you submit correct files.
# * Academic Integrity: Students are required to comply with the university policy on academic integrity found in the Code of Student Conduct found at http://policies.ncsu.edu/policy/pol-11-35-01
# * Academic Honesty: See http://policies.ncsu.edu/policy/pol-11-35-01  for a detailed explanation of academic honesty.

# %% [markdown]
# ## Import libraries to be Used

# %%
## Standard libraries
import os
import json
import math
import random
import numpy as np 
import copy
import time

## Imports for plotting
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
sns.set_theme()

## Progress bar
from tqdm.notebook import tqdm

## typing
from typing import (
    Any,
    Callable,
    Dict,
    List,
    Optional,
    Sequence,
    Set,
    Tuple,
    Type,
    Union,
)

try:
    from typing import Literal
except ImportError:
    from typing_extensions import Literal

## PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import torch.optim as optim

## PyTorch Torchvision
import torchvision
from torchvision.datasets import CIFAR10
from torchvision import transforms

# %% [markdown]
# ### Identify the system

# %%
import platform
from mmengine.utils.dl_utils import collect_env
from pprint import pprint

print("=" * 40, "System Information", "=" * 40)
uname = platform.uname()
print(f"System: {uname.system}")
print(f"Node Name: {uname.node}")
print(f"Release: {uname.release}")
print(f"Version: {uname.version}")
print(f"Machine: {uname.machine}")
print(f"Processor: {uname.processor}")

print("=" * 40, "Environment Information", "=" * 40)
my_env = collect_env()
pprint(my_env)
# Out:
# ======================================== System Information ========================================
# System: Windows
# Node Name: MSI
# Release: 10
# Version: 10.0.22631
# Machine: AMD64
# Processor: Intel64 Family 6 Model 154 Stepping 3, GenuineIntel
# ======================================== Environment Information ========================================
# OrderedDict([('sys.platform', 'win32'),
#              ('Python',
#               '3.11.7 | packaged by Anaconda, Inc. | (main, Dec 15 2023, '
#               '18:05:47) [MSC v.1916 64 bit (AMD64)]'),
#              ('CUDA available', True),
#              ('MUSA available', False),
#              ('numpy_random_seed', 2147483648),
#              ('GPU 0', 'NVIDIA GeForce RTX 3070 Laptop GPU'),
#              ('CUDA_HOME', None),
#              ('GCC', 'n/a'),
#              ('PyTorch', '2.1.2'),
#              ('PyTorch compiling details',
#               'PyTorch built with:\n'
#               '  - C++ Version: 199711\n'
#               '  - MSVC 192930151\n'
#               '  - Intel(R) Math Kernel Library Version 2020.0.2 Product Build '
#               '20200624 for Intel(R) 64 architecture applications\n'
#               '  - Intel(R) MKL-DNN v3.1.1 (Git Hash '
#               '64f6bcbcbab628e96f33a62c3e975f8535a7bde4)\n'
#               '  - OpenMP 2019\n'
#               '  - LAPACK is enabled (usually provided by MKL)\n'
#               '  - CPU capability usage: AVX2\n'
#               '  - CUDA Runtime 11.8\n'
#               '  - NVCC architecture flags: '
#               '-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_90,code=sm_90;-gencode;arch=compute_37,code=compute_37\n'
#               '  - CuDNN 8.7\n'
#               '  - Magma 2.5.4\n'
#               '  - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, '
#               'CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, '
#               'CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, '
#               'CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /bigobj /FS '
#               '-DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI '
#               '-DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK '
#               '-DSYMBOLICATE_MOBILE_DEBUG_HANDLE /utf-8 /wd4624 /wd4068 '
#               '/wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, '
#               'LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, '
#               'PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=OFF, '
#               'TORCH_VERSION=2.1.2, USE_CUDA=ON, USE_CUDNN=ON, '
#               'USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, '
#               'USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, '
#               'USE_OPENMP=ON, USE_ROCM=OFF, \n'),
#              ('TorchVision', '0.16.2'),
#              ('MMEngine', '0.10.3')])

# %% [markdown]
# ## Set Random Seeds and Devices

# %%
# Function for setting the seed
def random_seed(seed: int = 42, rank: int = 0, deterministic: bool = False) -> None:
    # TODO: 2 points  - write your code below
    seed += rank  
    
    # Set Python's built-in random module seed
    random.seed(seed)
    
    # Set NumPy's random seed
    np.random.seed(seed)
    
    # Set PyTorch's random seed (if available)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # If using multiple GPUs

    # Ensure deterministic behavior in PyTorch (if needed)
    if deterministic:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    # raise NotImplementedError # comment it out after you write your code

seed = 42
random_seed(seed=seed, deterministic=True)

# Fetching the device that will be used throughout this notebook
device = (
    torch.device("cpu") if not torch.cuda.is_available() else torch.device("cuda:0")
)
print("Using device", device)
# Out:
# Using device cuda:0

# %% [markdown]
# ## Prepare Datasets (CIFAR10)

# %%
# Path to the folder where the datasets are/should be downloaded (e.g. CIFAR10)
DATASET_PATH = "../data"
# Path to the folder where the pretrained models are saved
CHECKPOINT_PATH = "../checkpoints/ece763_proj_01"
os.makedirs(CHECKPOINT_PATH, exist_ok=True)

# %% [markdown]
# ### CIFAR10
# CIFAR10 is a very popular dataset for computer vision on low-resolution images (32x32 pixels). The task is to classify images into one of 10 classes: **airplane, automobile, bird, cat, deer, dog, frog, horse, ship, and truck**.

# %%
# Dataset statistics for normalizing the input values to zero mean and one std
DATA_MEANS = [0.491, 0.482, 0.447]
DATA_STD = [0.247, 0.243, 0.261]

# Transformations are applied on images when we want to access them. Here, we push the images into a tensor
# and normalize the values. However, you can use more transformations, like augmentations to prevent overfitting.
# Feel free to experiment with augmentations here once you have a first running MLP, but remember to not apply
# any augmentations on the test data!
data_transforms = transforms.Compose([transforms.ToTensor(),
                                      transforms.Normalize(DATA_MEANS, DATA_STD)
                                     ])

# Loading the training dataset. We need to split it into a training and validation part
main_dataset = CIFAR10(root=DATASET_PATH, train=True, transform=data_transforms, download=True)
train_set, val_set = torch.utils.data.random_split(main_dataset, [45000, 5000], generator=torch.Generator().manual_seed(seed))

# Loading the test set
test_set = CIFAR10(root=DATASET_PATH, train=False, transform=data_transforms, download=True)

# Create data loaders for later
train_loader = data.DataLoader(train_set, batch_size=128, shuffle=True, drop_last=True, pin_memory=True, num_workers=3)
val_loader = data.DataLoader(val_set, batch_size=128, shuffle=False, drop_last=False, num_workers=3)
test_loader = data.DataLoader(test_set, batch_size=128, shuffle=False, drop_last=False, num_workers=3)

# classes
classes = (
    "plane",
    "car",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck"
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# When working with data, it is always recommend to look at the data before blaming your model for not performing well if the data was incorrectly processed. Hence, let's plot 1-batch images of the CIFAR10 training dataset:

# %%
start_time = time.time()
dataiter = iter(train_loader)
images, labels = next(dataiter)
end_time = time.time()
print(f"Time for loading a batch: {(end_time - start_time):6.5f}s")
# Out:
# Time for loading a batch: 15.01998s

# %%
INV_DATA_MEANS = torch.tensor([-m for m in DATA_MEANS]).view(-1, 1, 1)
INV_DATA_STD = torch.tensor([1.0 / s for s in DATA_STD]).view(-1, 1, 1)

def imshow(img):
    img = img.div_(INV_DATA_STD).sub_(INV_DATA_MEANS) # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    plt.show()
    plt.close()


imshow(torchvision.utils.make_grid(images))
print("GroundTruth (1st row): ", " ".join(f"{classes[labels[j]]:5s}" for j in range(8)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# GroundTruth (1st row):  cat   frog  car   dog   frog  car   truck frog

# %% [markdown]
# Now we are all set. So, let's dive into implementing our own MLP and ConvNet!

# %% [markdown]
# ## Part 0: Optimizer
#
# To gain a better insight in the training of the neural networks, let's implement our own optimizer. First, we need to understand what an optimizer actually does. The optimizer is responsible to update the network's parameters given the gradients. Hence, we effectively implement a function $w^{t} = f(w^{t-1}, g^{t}, ...)$ with $w$ being the parameters, and $g^{t} = \nabla_{w^{(t-1)}} \mathcal{L}^{(t)}$ the gradients at time step $t$. A common, additional parameter to this function is the learning rate, here denoted by $\eta$. Usually, the learning rate can be seen as the "step size" of the update. A higher learning rate means that we change the weights more in the direction of the gradients, a smaller means we take shorter steps.
#
# As most optimizers only differ in the implementation of $f$, we can define a template for an optimizer in PyTorch below. We take as input the parameters of a model and a learning rate. The function `zero_grad` sets the gradients of all parameters to zero, which we have to do before calling `loss.backward()`. Finally, the `step()` function tells the optimizer to update all weights based on their gradients. The template is setup below:

# %%
class OptimizerTemplate:
    
    def __init__(self, params: nn.ParameterList, lr: float)->None:
        self.params = list(params)
        self.lr = lr
        
    def zero_grad(self)->None:
        ## Set gradients of all parameters to zero
        for p in self.params:
            if p.grad is not None:
                p.grad.detach_() # For second-order optimizers important
                p.grad.zero_()
    
    @torch.no_grad()
    def step(self)->None:
        ## Apply update step to all parameters
        for p in self.params:
            if p.grad is None: # We skip parameters without any gradients
                continue
            self.update_param(p)
            
    def update_param(self, p: nn.Parameter)->None:
        # To be implemented in optimizer-specific classes
        raise NotImplementedError

# %% [markdown]
# The optimizer we are going to implement is the standard Stochastic Gradient Descent (SGD) with momentum. Plain SGD updates the parameters using the following equation:
#
# $$
# \begin{split}
#     w^{(t)} & = w^{(t-1)} - \eta \cdot g^{(t)}
# \end{split}
# $$
#
# The concept of momentum replaces the gradient in the update by an exponential average of all past gradients including the current one, which allows for a smoother training. The gradient update with momentum becomes:
#
# $$
# \begin{split}
#     m^{(t)} & = \beta_1 m^{(t-1)} + (1 - \beta_1)\cdot g^{(t)}\\
#     w^{(t)} & = w^{(t-1)} - \eta \cdot m^{(t)}\\
# \end{split}
# $$
#
# Let's implement the optimizer below:

# %%
class SGDMomentum(OptimizerTemplate):
    
    def __init__(self, params: nn.ParameterList, lr: float, momentum: float=0.9)->None:
        super().__init__(params, lr)
        self.momentum = momentum # Corresponds to beta_1 in the equation above
        self.param_momentum = {p: torch.zeros_like(p.data) for p in self.params} # Dict to store m_t
        
    def update_param(self, p:nn.Parameter)->None:
        # TODO: 10 points -- Implement the gradient update
        """
            m_t = beta_1 * m_{t-1} + (1 - beta_1) * ∇L
            p_t = p_t - lr * m_t
        """
        if p.grad is None:
            return  # Skip if no gradient
        
        # Compute momentum update
        self.param_momentum[p] = self.momentum * self.param_momentum[p] + (1-self.momentum) * p.grad

        # Apply update to parameter
        p.data -= self.lr * self.param_momentum[p]
        # raise NotImplementedError

# %% [markdown]
# To verify that our optimizer is working, let's create a challenging surface over two parameter dimensions which we want to optimize to find the optimum:

# %%
def pathological_curve_loss(w1: float, w2: float) -> float:
    # Example of a pathological curvature. There are many more possible, feel free to experiment here!
    x1_loss = torch.tanh(w1)**2 + 0.01 * torch.abs(w1)
    x2_loss = torch.sigmoid(w2)
    return x1_loss + x2_loss

# %%
def plot_curve(curve_fn, x_range: Tuple[float, float] = (-5,5), y_range: Tuple[float, float]=(-5,5), plot_3d: bool=False, cmap=cm.viridis, title: str="Pathological curvature"):
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(projection="3d") if plot_3d else fig.add_subplot()

    x = torch.arange(x_range[0], x_range[1], (x_range[1]-x_range[0])/100.)
    y = torch.arange(y_range[0], y_range[1], (y_range[1]-y_range[0])/100.)
    x, y = torch.meshgrid([x,y], indexing='ij')
    z = curve_fn(x, y)
    x, y, z = x.numpy(), y.numpy(), z.numpy()

    if plot_3d:
        ax.plot_surface(x, y, z, cmap=cmap, linewidth=1, color="#000", antialiased=False)
        ax.set_zlabel("loss")
    else:
        ax.imshow(z.T[::-1], cmap=cmap, extent=(x_range[0], x_range[1], y_range[0], y_range[1]))
    plt.title(title)
    ax.set_xlabel(r"$w_1$")
    ax.set_ylabel(r"$w_2$")
    plt.tight_layout()
    return ax

sns.reset_orig()
_ = plot_curve(pathological_curve_loss, plot_3d=True)
plt.show()

# %% [markdown]
# In terms of optimization, you can image that $w_1$ and $w_2$ are weight parameters, and the curvature represents the loss surface over the space of $w_1$ and $w_2$. Note that in typical networks, we have many, many more parameters than two, and such curvatures can occur in multi-dimensional spaces as well.
#
# Ideally, our optimization algorithm would find the center of the ravine and focuses on optimizing the parameters towards the direction of $w_2$. However, if we encounter a point along the ridges, the gradient is much greater in $w_1$ than $w_2$, and we might end up jumping from one side to the other. Due to the large gradients, we would have to reduce our learning rate slowing down learning significantly.
#
# To test our algorithms, we can implement a simple function to train two parameters on such a surface:

# %%
def train_curve(optimizer_func, curve_func=pathological_curve_loss, num_updates=100, init=[5,5]):
    """
    Inputs:
        optimizer_func - Constructor of the optimizer to use. Should only take a parameter list
        curve_func - Loss function (e.g. pathological curvature)
        num_updates - Number of updates/steps to take when optimizing 
        init - Initial values of parameters. Must be a list/tuple with two elements representing w_1 and w_2
    Outputs:
        Numpy array of shape [num_updates, 3] with [t,:2] being the parameter values at step t, and [t,2] the loss at t.
    """
    weights = nn.Parameter(torch.FloatTensor(init), requires_grad=True)
    optimizer = optimizer_func([weights])
    
    list_points = []
    for _ in range(num_updates):
        # TODO: 8 points -- Determine the loss for the current weights, save the weights and loss, perform backpropagation
        optimizer.zero_grad()  # Zero out gradients
        
        w1, w2 = weights[0], weights[1]
        loss = curve_func(w1, w2)  # Determine loss based on the current weights
        
        # Save weights and loss
        list_points.append(torch.cat((weights.data, loss.unsqueeze(0))))
        
        loss.backward()  # Determine gradients from backpropagation
        optimizer.step()  # Perform optimizer update step
        # raise NotImplementedError
        
        
    points = torch.stack(list_points, dim=0).detach().cpu().numpy()
    return points

# %% [markdown]
# Next, let's apply the optimizer on our curvature. Note that we set a much higher learning rate for the optimization algorithms as you would in a standard neural network. This is because we only have 2 parameters instead of tens of thousands or even millions.

# %%
SGDMom_points = train_curve(lambda params: SGDMomentum(params, lr=10, momentum=0.9))
print(SGDMom_points)
# Out:
# [[ 5.00000000e+00  5.00000000e+00  2.04312563e+00]
#  [ 4.98963690e+00  4.99335194e+00  2.04297376e+00]
#  [ 4.96993923e+00  4.98067713e+00  2.04268408e+00]
#  [ 4.94182587e+00  4.96249342e+00  2.04226732e+00]
#  [ 4.90611601e+00  4.93922949e+00  2.04173279e+00]
#  [ 4.86353874e+00  4.91123343e+00  2.04108715e+00]
#  [ 4.81474209e+00  4.87878084e+00  2.04033566e+00]
#  [ 4.76029921e+00  4.84208155e+00  2.03948092e+00]
#  [ 4.70071411e+00  4.80128479e+00  2.03852463e+00]
#  [ 4.63642693e+00  4.75648212e+00  2.03746605e+00]
#  [ 4.56781721e+00  4.70770979e+00  2.03630257e+00]
#  [ 4.49520683e+00  4.65494967e+00  2.03502893e+00]
#  [ 4.41886139e+00  4.59812975e+00  2.03363776e+00]
#  [ 4.33898973e+00  4.53712082e+00  2.03211832e+00]
#  [ 4.25574398e+00  4.47173405e+00  2.03045464e+00]
#  [ 4.16921473e+00  4.40171528e+00  2.02862811e+00]
#  [ 4.07942724e+00  4.32673740e+00  2.02661180e+00]
#  [ 3.98633146e+00  4.24638891e+00  2.02437162e+00]
#  [ 3.88979101e+00  4.16016054e+00  2.02186131e+00]
#  [ 3.78956485e+00  4.06742573e+00  2.01902056e+00]
#  [ 3.68528152e+00  3.96741462e+00  2.01576710e+00]
#  [ 3.57640314e+00  3.85917854e+00  2.01198840e+00]
#  [ 3.46217084e+00  3.74154282e+00  2.00752711e+00]
#  [ 3.34152436e+00  3.61303926e+00  2.00215840e+00]
#  [ 3.21297693e+00  3.47181416e+00  1.99554992e+00]
#  [ 3.07441592e+00  3.31549430e+00  1.98719311e+00]
#  [ 2.92276859e+00  3.14099097e+00  1.97627544e+00]
#  [ 2.75340962e+00  2.94420815e+00  1.96141815e+00]
#  [ 2.55903697e+00  2.71959376e+00  1.94009733e+00]
#  [ 2.32733297e+00  2.45943642e+00  1.90716815e+00]
#  [ 2.03550005e+00  2.15274525e+00  1.85030890e+00]
#  [ 1.63533473e+00  1.78347993e+00  1.73147011e+00]
#  [ 1.00380623e+00  1.32796693e+00  1.38299823e+00]
#  [-2.11898565e-01  7.52397895e-01  7.25410223e-01]
#  [-8.96668613e-01  1.66781545e-02  1.02389205e+00]
#  [-8.03663671e-01 -8.95452201e-01  7.41685152e-01]
#  [ 3.11712623e-02 -1.92226362e+00  1.28892094e-01]
#  [ 7.10260808e-01 -2.95771909e+00  4.29601520e-01]
#  [ 5.45601487e-01 -3.93656421e+00  2.71821707e-01]
#  [-3.61176848e-01 -4.83629990e+00  1.31374851e-01]
#  [-5.57800174e-01 -5.65387392e+00  2.65453339e-01]
#  [ 2.82893777e-02 -6.39316988e+00  2.75290664e-03]
#  [ 4.89251554e-01 -7.06020355e+00  2.11523473e-01]
#  [ 1.73559606e-01 -7.66139126e+00  3.17341983e-02]
#  [-4.54090297e-01 -8.20293045e+00  1.85656860e-01]
#  [-3.12272549e-01 -8.69058895e+00  9.47989821e-02]
#  [ 3.75006616e-01 -9.12965012e+00  1.32282615e-01]
#  [ 3.58876526e-01 -9.52491379e+00  1.22151978e-01]
#  [-2.72514343e-01 -9.88072395e+00  7.35125393e-02]
#  [-3.36466789e-01 -1.02010040e+01  1.08584911e-01]
#  [ 1.96389079e-01 -1.04892931e+01  3.95899452e-02]
#  [ 2.92734891e-01 -1.07487812e+01  8.39744732e-02]
#  [-1.53726071e-01 -1.09823418e+01  2.48185843e-02]
#  [-2.47584835e-01 -1.11925631e+01  6.13672063e-02]
#  [ 1.34663388e-01 -1.13817768e+01  1.92752611e-02]
#  [ 2.05772936e-01 -1.15520802e+01  4.32426445e-02]
#  [-1.29352093e-01 -1.17053623e+01  1.78488512e-02]
#  [-1.67950794e-01 -1.18433247e+01  2.93720793e-02]
#  [ 1.30875781e-01 -1.19674978e+01  1.82498675e-02]
#  [ 1.33959979e-01 -1.20792599e+01  1.90780256e-02]
#  [-1.34870231e-01 -1.21798515e+01  1.93254817e-02]
#  [-1.03519171e-01 -1.22703896e+01  1.16800033e-02]
#  [ 1.38803646e-01 -1.23518782e+01  2.04140190e-02]
#  [ 7.63030201e-02 -1.24252224e+01  6.56667305e-03]
#  [-1.41374782e-01 -1.24912357e+01  2.11410057e-02]
#  [-5.19440100e-02 -1.25506516e+01  3.21631669e-03]
#  [ 1.42058820e-01 -1.26041298e+01  2.13362183e-02]
#  [ 3.00593451e-02 -1.26522636e+01  1.20681385e-03]
#  [-1.40786499e-01 -1.26955872e+01  2.09727678e-02]
#  [-1.02924705e-02 -1.27345810e+01  2.11799575e-04]
#  [ 1.37734190e-01 -1.27696791e+01  2.01135240e-02]
#  [-7.65329599e-03 -1.28012695e+01  1.37860887e-04]
#  [-1.13196641e-01 -1.28297043e+01  1.38394590e-02]
#  [ 2.43815482e-02 -1.28552980e+01  8.40652094e-04]
#  [ 8.94774348e-02 -1.28783350e+01  8.86099879e-03]
#  [-3.89937311e-02 -1.28990707e+01  1.91140873e-03]
#  [-6.67882115e-02 -1.29177351e+01  5.11776982e-03]
#  [ 5.09817153e-02 -1.29345360e+01  3.10686883e-03]
#  [ 4.53637987e-02 -1.29496593e+01  2.51106918e-03]
#  [-6.01714104e-02 -1.29632721e+01  4.21593664e-03]
#  [-2.53894366e-02 -1.29755259e+01  9.00557265e-04]
#  [ 6.66496009e-02 -1.29865570e+01  5.09783439e-03]
#  [ 6.97205961e-03 -1.29964876e+01  1.20596917e-04]
#  [-7.06809387e-02 -1.30054274e+01  5.68826171e-03]
#  [ 9.85562801e-03 -1.30134754e+01  1.97913454e-04]
#  [ 5.26298285e-02 -1.30207205e+01  3.29330424e-03]
#  [-2.37452015e-02 -1.30272436e+01  8.03274335e-04]
#  [-3.50280069e-02 -1.30331163e+01  1.57842506e-03]
#  [ 3.47589813e-02 -1.30384045e+01  1.55697938e-03]
#  [ 1.81611888e-02 -1.30431652e+01  5.13533014e-04]
#  [-4.30832356e-02 -1.30474520e+01  2.28685862e-03]
#  [-2.24965811e-03 -1.30513124e+01  2.97047936e-05]
#  [ 4.89998497e-02 -1.30547895e+01  2.88928533e-03]
#  [-1.25622079e-02 -1.30579205e+01  2.85547692e-04]
#  [-3.28489281e-02 -1.30607405e+01  1.40889292e-03]
#  [ 2.44964473e-02 -1.30632811e+01  8.46922107e-04]
#  [ 1.71535648e-02 -1.30655699e+01  4.67839593e-04]
#  [-3.37487049e-02 -1.30676317e+01  1.47771020e-03]
#  [-2.16573849e-03 -1.30694895e+01  2.84563812e-05]
#  [ 4.05903794e-02 -1.30711632e+01  2.05377978e-03]]

# %% [markdown]
# To understand best how the different algorithms worked, we visualize the update step as a line plot through the loss surface. We will stick with a 2D representation for readability.

# %%
all_points = SGDMom_points
ax = plot_curve(pathological_curve_loss,
                x_range=(-np.absolute(all_points[:,0]).max(), np.absolute(all_points[:,0]).max()),
                y_range=(all_points[:,1].min(), all_points[:,1].max()),
                plot_3d=False)
ax.plot(SGDMom_points[:,0], SGDMom_points[:,1], color="red", marker="o", zorder=2, label="SGDMom")
plt.legend()
plt.show()

# %% [markdown]
# If the implementation is correct, you should see that the optimizer indeed reaches a point of very low $w_2$ ($w_2 < -7.5$) and $w_1\approx 0$. If not, go back to your optimizer implementation and check what could go wrong.

# %% [markdown]
# ## Part 1. Generic training and validation function
#
# Now that we the optimizer implemented, and the dataset loaded, we can look at implementing our own training functions.

# %%
def train_one_epoch(model: nn.Module, optimizer: OptimizerTemplate, loss_module, data_loader)->Tuple[float, int]:
    true_preds, count = 0.0, 0
    model.train()
    for imgs, labels in data_loader:
        # TODO: 10 points -- Implement training loop with training on classification
        imgs, labels = imgs.to(device), labels.to(device)  # Move data to the same device as model
        
        optimizer.zero_grad()  # Clear previous gradients
        imgs = imgs.view(imgs.size(0), -1)  # Flatten input to (batch_size, num_features)
        outputs = model(imgs)  # Forward pass
        
        loss = loss_module(outputs, labels)  # Compute loss
        
        loss.backward()  # Backpropagation
        optimizer.step()  # Update model weights

        # Compute predictions
        preds = outputs.argmax(dim=1)  # Get predicted class index
        true_preds += (preds == labels).sum().item()  # Count correct predictions
        count += labels.size(0)  # Count total samples
        # raise NotImplementedError
       
        # Record statistics during training
        
    train_acc = true_preds / count
    return train_acc

# %%
@torch.no_grad()
def test_model(model, data_loader):
    # TODO: 10 points - Test model and return accuracy
    model.eval()  # Set model to evaluation mode
    true_preds, count = 0.0, 0

    for imgs, labels in data_loader:
        imgs, labels = imgs.to(device), labels.to(device)

        imgs = imgs.view(imgs.size(0), -1) 
        outputs = model(imgs) 
        preds = outputs.argmax(dim=1) 

        true_preds += (preds == labels).sum().item()  
        count += labels.size(0)  

    accuracy = true_preds / count  # Compute accuracy percentage
    return accuracy
    # raise NotImplementedError

# %%
def save_model(model, model_name, root_dir=CHECKPOINT_PATH):
    # TODO: 2 points -- Save the parameters of the model
    os.makedirs(root_dir, exist_ok=True)  # Ensure the directory exists
    model_path = os.path.join(root_dir, f"{model_name}.pt")
    
    torch.save(model.state_dict(), model_path)
    print(f"Model saved to {model_path}")
    # raise NotImplementedError
    

def load_model(model, model_name, root_dir=CHECKPOINT_PATH):
    # TODO: 2 points -- Load the parameters of the model
    model_path = os.path.join(root_dir, f"{model_name}.pt")
    
    if not os.path.exists(model_path):
        raise FileNotFoundError(f"No checkpoint found at {model_path}")
    
    model.load_state_dict(torch.load(model_path, map_location=device))
    
    print(f"Model loaded from {model_path}")
    return model
    # raise NotImplementedError

# %%
def train_model(model, optimizer, loss_module, train_data_loader, val_data_loader, num_epochs=25, model_name="MyModel"):
    # Set model to train mode
    model.to(device)
    best_val_acc = -1.0

    # Training loop
    for epoch in range(1, num_epochs+1):
        train_acc = train_one_epoch(model, optimizer, loss_module, train_data_loader)

        if epoch % 5 == 0 or epoch == num_epochs:
            # Evaluate the model and save if best
            acc = test_model(model, val_data_loader)
            if acc > best_val_acc:
                best_val_acc = acc 
                save_model(model, model_name, CHECKPOINT_PATH)

            print(
                f"[Epoch {epoch+1:2d}] Training accuracy: {train_acc*100.0:05.2f}%, Validation accuracy: {acc*100.0:05.2f}%, Best validation accuracy: {best_val_acc*100.0:05.2f}%"
            )

    # Load best model after training
    model = load_model(model, model_name, CHECKPOINT_PATH)
    return model

# %% [markdown]
# ## Part 2: Implementing the MLP

# %% [markdown]
# ### Part 2.1: Vanilla MLP Module
#
# You can make use of PyTorch's common functionalities, especially the `torch.nn` modules might be of help. The design choices of the MLP (e.g. the activation function) is left up to you, but for an initial setup, we recommend stacking linear layers with ReLU activation functions in between. Remember to not apply any activation function on the output.

# %%
class MLP(nn.Module):

    def __init__(self, input_dim: int=3072, num_classes: int=10, hidden_dims: List[int]=[256, 128], act_layer: nn.Module=nn.ReLU)->None:
        """
        Inputs:
            input_dim - Dimension of the input images in pixels
            num_classes - Number of classes we want to predict. The output size of the MLP
                          should be num_classes.
            hidden_dims - A list of integers specifying the hidden layer dimensions in the MLP. 
                           The MLP should have len(hidden_sizes)+1 linear layers.
            act_layer - Activation function.
        """
        super().__init__()
        # TODO: 5 points - Create the network based on the specified hidden sizes
        layers = []
        in_dim = input_dim
        
        # Creating hidden layers
        for hidden_dim in hidden_dims:
            layers.append(nn.Linear(in_dim, hidden_dim))
            layers.append(act_layer())
            in_dim = hidden_dim
        
        # Output layer
        layers.append(nn.Linear(in_dim, num_classes))
        
        self.model = nn.Sequential(*layers)
        # raise NotImplementedError
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # TODO: 5 points -- Apply the MLP on an input
        return self.model(x)
        # raise NotImplementedError

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters()) / 1e6

# %%
# Let's test the MLP implementation
input_dim = np.random.randint(low=64, high=3072)
num_classes = np.random.randint(low=5, high=20)
hidden_dims = [np.random.randint(low=32, high=256) for _ in range(np.random.randint(low=1, high=3))]
my_mlp = MLP(input_dim=input_dim, num_classes=num_classes, hidden_dims=hidden_dims)
my_mlp.to(device)
random_input = torch.randn(32, input_dim, device=device)
random_output = my_mlp(random_input)
assert random_output.shape[0] == random_input.shape[0]
assert random_output.shape[1] == num_classes

# %%
# Create model, optimizer, and start training
model_mlp = MLP(act_layer=nn.ReLU).to(device)
optimizer = SGDMomentum(model_mlp.parameters(), lr=0.1) # you may tune lr
loss_module = nn.CrossEntropyLoss().to(device)

print(f'model mlp created: {count_parameters(model_mlp):05.3f}M')
model_mlp=train_model(model_mlp, optimizer, loss_module, train_loader, val_loader, num_epochs=5, model_name="myMLP_ReLU")
# Out:
# model mlp created: 0.821M
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU.pt
# [Epoch  6] Training accuracy: 57.74%, Validation accuracy: 51.68%, Best validation accuracy: 51.68%
# Model loaded from ../checkpoints/ece763_proj_01\myMLP_ReLU.pt

# %%
# Test best model on test set
vanilla_mlp_test_acc = test_model(model_mlp, test_loader)
print(f'Test accuracy: {vanilla_mlp_test_acc*100.0:05.2f}%')
# Out:
# Test accuracy: 51.76%

# %% [markdown]
# It is expected that you reach with the default configurations a validation and test accuracy of $\sim51-53\%$ . If you have reached this performance, we can consider this task as completed!

# %% [markdown]
# ### Part 2.2: Improving the vanilla MLP
#
# Now that we have a basic MLP, let's try to improve over this default performance! Your task is to think about ways to maximize the performance of your MLP. Possible suggestions you can look at include:
#
# * Do data augmentations help the model to generalize?
# * Can regularization techniques (dropout, weight decay, etc.) help?
# * Do deeper models perform better? Or is it better to have wide networks?
# * Can normalization techniques (BatchNorm, LayerNorm, etc.) help?
#
# Your task is to improve your model to reach at least 56% on the test set! But can you get even above this? Consider this as a challenge!
#
# For this implementation, you can copy and then modify your codes above. List the changes that you have made and discuss what affect they have. Further, repeat the experiments for *at least 3 seeds* to report stable improvements.

# %%
# Data augmentation
data_transforms = transforms.Compose([                                     
                                      transforms.RandomHorizontalFlip(),  # Flip images randomly
                                      # transforms.RandomRotation(10),  # Rotate randomly by ±10 degrees
                                      transforms.RandomResizedCrop(32, scale=(0.8, 1.0)),  # Random crop
                                    #   transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # Color variation
                                      transforms.ToTensor(),  # Convert to tensor AFTER augmentation
                                      transforms.Normalize(DATA_MEANS, DATA_STD)
                                     ])

# Loading the training dataset. We need to split it into a training and validation part
main_dataset = CIFAR10(root=DATASET_PATH, train=True, transform=data_transforms, download=True)
train_set, val_set = torch.utils.data.random_split(main_dataset, [45000, 5000], generator=torch.Generator().manual_seed(seed))

# Loading the test set
test_set = CIFAR10(root=DATASET_PATH, train=False, transform=data_transforms, download=True)

# Create data loaders for later
train_loader = data.DataLoader(train_set, batch_size=128, shuffle=True, drop_last=True, pin_memory=True, num_workers=3)
val_loader = data.DataLoader(val_set, batch_size=128, shuffle=False, drop_last=False, num_workers=3)
test_loader = data.DataLoader(test_set, batch_size=128, shuffle=False, drop_last=False, num_workers=3)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Add additional hidden layers (Batch Normalization, LeakyReLU and Dropout)
class MLP(nn.Module):

    def __init__(self, input_dim: int=3072, num_classes: int=10, hidden_dims: List[int]=[256, 128], act_layer: nn.Module=nn.ReLU)->None:
        """
        Inputs:
            input_dim - Dimension of the input images in pixels
            num_classes - Number of classes we want to predict. The output size of the MLP
                          should be num_classes.
            hidden_dims - A list of integers specifying the hidden layer dimensions in the MLP. 
                           The MLP should have len(hidden_sizes)+1 linear layers.
            act_layer - Activation function.
        """
        super().__init__()
        layers = []
        in_dim = input_dim
        
        # Creating hidden layers
        for hidden_dim in hidden_dims:
            layers.append(nn.Linear(in_dim, hidden_dim))
            layers.append(nn.BatchNorm1d(hidden_dim))  # Batch Normalization
            layers.append(act_layer()) 
            # layers.append(nn.Dropout(0.5))  # Dropout layer
            in_dim = hidden_dim
        
        # Output layer
        layers.append(nn.Linear(in_dim, num_classes))
        
        self.model = nn.Sequential(*layers)
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.model(x)

# %%
# TODO: 10 points -- Improve the model and list the changes as code comments. 
# You may try different changes (e.g. those suggested above) individually or combine them. 
# You do not need to explore all the four suggestions above.
# You can create as many code blocks as you need. 

model_mlp_improved = MLP(act_layer=nn.ReLU).to(device)
optimizer = SGDMomentum(model_mlp_improved.parameters(), lr=0.1) # you may tune lr
loss_module = nn.CrossEntropyLoss().to(device)

print(f'model mlp created: {count_parameters(model_mlp_improved):05.3f}M')
model_mlp_improved=train_model(model_mlp_improved, optimizer, loss_module, train_loader, val_loader, num_epochs=15, model_name="myMLP_ReLU_Improved")

mlp_improved_test_acc = test_model(model_mlp_improved, test_loader)
print(f'Test accuracy: {mlp_improved_test_acc*100.0:05.2f}%')
# raise NotImplementedError
# Out:
# model mlp created: 0.822M
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# [Epoch  6] Training accuracy: 52.78%, Validation accuracy: 51.54%, Best validation accuracy: 51.54%
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# [Epoch 11] Training accuracy: 56.58%, Validation accuracy: 54.02%, Best validation accuracy: 54.02%
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# [Epoch 16] Training accuracy: 58.94%, Validation accuracy: 56.40%, Best validation accuracy: 56.40%
# Model loaded from ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# Test accuracy: 55.68%

# %%
seed = 1234
random_seed(seed=seed, deterministic=True)

train_set, val_set = torch.utils.data.random_split(main_dataset, [45000, 5000], generator=torch.Generator().manual_seed(seed))

# Create data loaders for later
train_loader = data.DataLoader(train_set, batch_size=128, shuffle=True, drop_last=True, pin_memory=True, num_workers=3)
val_loader = data.DataLoader(val_set, batch_size=128, shuffle=False, drop_last=False, num_workers=3)

# %%
model_mlp_improved = MLP(act_layer=nn.ReLU).to(device)
optimizer = SGDMomentum(model_mlp_improved.parameters(), lr=0.1) # you may tune lr
loss_module = nn.CrossEntropyLoss().to(device)

print(f'model mlp created: {count_parameters(model_mlp_improved):05.3f}M')
model_mlp_improved=train_model(model_mlp_improved, optimizer, loss_module, train_loader, val_loader, num_epochs=15, model_name="myMLP_ReLU_Improved")

mlp_improved_test_acc = test_model(model_mlp_improved, test_loader)
print(f'Test accuracy: {mlp_improved_test_acc*100.0:05.2f}%')
# Out:
# model mlp created: 0.822M
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# [Epoch  6] Training accuracy: 52.31%, Validation accuracy: 52.60%, Best validation accuracy: 52.60%
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# [Epoch 11] Training accuracy: 56.37%, Validation accuracy: 53.98%, Best validation accuracy: 53.98%
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# [Epoch 16] Training accuracy: 58.89%, Validation accuracy: 55.94%, Best validation accuracy: 55.94%
# Model loaded from ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# Test accuracy: 55.62%

# %%
seed = 1337
random_seed(seed=seed, deterministic=True)

train_set, val_set = torch.utils.data.random_split(main_dataset, [45000, 5000], generator=torch.Generator().manual_seed(seed))

# Create data loaders for later
train_loader = data.DataLoader(train_set, batch_size=128, shuffle=True, drop_last=True, pin_memory=True, num_workers=3)
val_loader = data.DataLoader(val_set, batch_size=128, shuffle=False, drop_last=False, num_workers=3)

# %%
model_mlp_improved = MLP(act_layer=nn.ReLU).to(device)
optimizer = SGDMomentum(model_mlp_improved.parameters(), lr=0.1) # you may tune lr
loss_module = nn.CrossEntropyLoss().to(device)

print(f'model mlp created: {count_parameters(model_mlp_improved):05.3f}M')
model_mlp_improved=train_model(model_mlp_improved, optimizer, loss_module, train_loader, val_loader, num_epochs=15, model_name="myMLP_ReLU_Improved")

mlp_improved_test_acc = test_model(model_mlp_improved, test_loader)
print(f'Test accuracy: {mlp_improved_test_acc*100.0:05.2f}%')
# Out:
# model mlp created: 0.822M
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# [Epoch  6] Training accuracy: 52.52%, Validation accuracy: 52.04%, Best validation accuracy: 52.04%
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# [Epoch 11] Training accuracy: 56.74%, Validation accuracy: 55.10%, Best validation accuracy: 55.10%
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# [Epoch 16] Training accuracy: 59.02%, Validation accuracy: 55.66%, Best validation accuracy: 55.66%
# Model loaded from ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# Test accuracy: 56.11%

# %%
seed = 9999
random_seed(seed=seed, deterministic=True)

train_set, val_set = torch.utils.data.random_split(main_dataset, [45000, 5000], generator=torch.Generator().manual_seed(seed))

# Create data loaders for later
train_loader = data.DataLoader(train_set, batch_size=128, shuffle=True, drop_last=True, pin_memory=True, num_workers=3)
val_loader = data.DataLoader(val_set, batch_size=128, shuffle=False, drop_last=False, num_workers=3)

# %%
model_mlp_improved = MLP(act_layer=nn.ReLU).to(device)
optimizer = SGDMomentum(model_mlp_improved.parameters(), lr=0.1) # you may tune lr
loss_module = nn.CrossEntropyLoss().to(device)

print(f'model mlp created: {count_parameters(model_mlp_improved):05.3f}M')
model_mlp_improved=train_model(model_mlp_improved, optimizer, loss_module, train_loader, val_loader, num_epochs=15, model_name="myMLP_ReLU_Improved")

mlp_improved_test_acc = test_model(model_mlp_improved, test_loader)
print(f'Test accuracy: {mlp_improved_test_acc*100.0:05.2f}%')
# Out:
# model mlp created: 0.822M
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# [Epoch  6] Training accuracy: 52.58%, Validation accuracy: 53.10%, Best validation accuracy: 53.10%
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# [Epoch 11] Training accuracy: 56.61%, Validation accuracy: 56.16%, Best validation accuracy: 56.16%
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# [Epoch 16] Training accuracy: 58.57%, Validation accuracy: 56.62%, Best validation accuracy: 56.62%
# Model loaded from ../checkpoints/ece763_proj_01\myMLP_ReLU_Improved.pt
# Test accuracy: 55.90%

# %%
# Change back to original data
data_transforms = transforms.Compose([                                     
                                      transforms.ToTensor(), 
                                      transforms.Normalize(DATA_MEANS, DATA_STD)
                                     ])

# Loading the training dataset. We need to split it into a training and validation part
main_dataset = CIFAR10(root=DATASET_PATH, train=True, transform=data_transforms, download=True)
train_set, val_set = torch.utils.data.random_split(main_dataset, [45000, 5000], generator=torch.Generator().manual_seed(seed))

# Loading the test set
test_set = CIFAR10(root=DATASET_PATH, train=False, transform=data_transforms, download=True)

# Create data loaders for later
train_loader = data.DataLoader(train_set, batch_size=128, shuffle=True, drop_last=True, pin_memory=True, num_workers=3)
val_loader = data.DataLoader(val_set, batch_size=128, shuffle=False, drop_last=False, num_workers=3)
test_loader = data.DataLoader(test_set, batch_size=128, shuffle=False, drop_last=False, num_workers=3)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# Observation:
# 1. Data augmentation helps the model to generalize conditionally. Some transformation techniques reduce overall accuracy.
# 2. Normalization increases accuracy but Dropout does the opposite.

# %% [markdown]
# ### Part 2.3: Investigating the limitations of MLP
#
# Now that we have seen how we can optimize our MLP, it is good to investigate the limitations of the model as well. Images have a natural grid structure where close-by pixels are strongly related. Does the MLP make use of this structure? To investigate this question, we will run two experiments:
#
# * Create a shuffle of pixels at the beginning of the training, and use the same shuffle throughout the training and validation.
# * At each training and validation step, sample a new shuffle of pixels.
#
#
# It is up to you whether you perform this investigation on the original plain MLP version or your optimized one. Implement a corresponding train and test function that support both variants of shuffling, and train two models.

# %%
class MLP(nn.Module):

    def __init__(self, input_dim: int=3072, num_classes: int=10, hidden_dims: List[int]=[256, 128], act_layer: nn.Module=nn.ReLU)->None:
        """
        Inputs:
            input_dim - Dimension of the input images in pixels
            num_classes - Number of classes we want to predict. The output size of the MLP
                          should be num_classes.
            hidden_dims - A list of integers specifying the hidden layer dimensions in the MLP. 
                           The MLP should have len(hidden_sizes)+1 linear layers.
            act_layer - Activation function.
        """
        super().__init__()
        # TODO: 5 points - Create the network based on the specified hidden sizes
        layers = []
        in_dim = input_dim
        
        # Creating hidden layers
        for hidden_dim in hidden_dims:
            layers.append(nn.Linear(in_dim, hidden_dim))
            layers.append(act_layer())
            in_dim = hidden_dim
        
        # Output layer
        layers.append(nn.Linear(in_dim, num_classes))
        
        self.model = nn.Sequential(*layers)
        # raise NotImplementedError
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # TODO: 5 points -- Apply the MLP on an input
        return self.model(x)
        # raise NotImplementedError

# %%
# TODO: 2 points - create a function that shuffles pixel values of images
def shuffle_pixels(imgs: torch.Tensor, shuffle_idx_shared: Optional[torch.Tensor] = None) -> torch.Tensor:
    B, C, H, W = imgs.shape
    imgs_flat = imgs.view(B, C, -1)  # Flatten the spatial dimensions
    if shuffle_idx_shared is not None:
        # shuffle the pixels using the provided shuffle idx
        shuffled_imgs_flat = imgs_flat[:, :, shuffle_idx_shared]
        # raise NotImplementedError
    else:
        # Sample a shuffle idx and then shuffle the pixels
        shuffle_idx = torch.randperm(H * W, device=imgs.device)  # Random permutation of indices
        shuffled_imgs_flat = imgs_flat[:, :, shuffle_idx]
        # raise NotImplementedError
        
    # Reshape back to original shape
    shuffled_imgs = shuffled_imgs_flat.view(B, C, H, W)
    return shuffled_imgs

# %%
# visualized the effects of pixel shuffle
images_pixelshuffled = shuffle_pixels(images)
print(images_pixelshuffled.shape)
imshow(torchvision.utils.make_grid(images_pixelshuffled))
print("GroundTruth (1st row): ", " ".join(f"{classes[labels[j]]:5s}" for j in range(8)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# torch.Size([128, 3, 32, 32])
# GroundTruth (1st row):  cat   frog  car   dog   frog  car   truck frog

# %%
# Create a training and test function that supports the shuffling of pixels, either fixed and shared among the entire dataset or newly generated for each batch

def train_one_epoch_pixelshuffled(
    model: nn.Module,
    optimizer: OptimizerTemplate,
    loss_module,
    data_loader,
    shuffle_idx_shared: Optional[torch.Tensor] = None,
) -> Tuple[float, int]:
    true_preds, count = 0.0, 0
    model.train()
    for imgs, labels in data_loader:
        # TODO: 2 points - Implement training loop with training on classification
        imgs, labels = imgs.to(device), labels.to(device)
        shuffled_imgs = shuffle_pixels(imgs, shuffle_idx_shared)

        optimizer.zero_grad()
        shuffled_imgs = shuffled_imgs.view(shuffled_imgs.size(0), -1)
        outputs = model(shuffled_imgs)
        loss = loss_module(outputs, labels)
        loss.backward()
        optimizer.step()

        true_preds += (outputs.argmax(dim=1) == labels).sum().item()
        count += labels.size(0)
        # raise NotImplementedError
        # Record statistics during training
    train_acc = (true_preds / count) if count > 0 else 0.0
    return train_acc

# %%
@torch.no_grad()
def test_model_pixelshuffled(
    model: nn.Module,
    data_loader,
    shuffle_idx_shared: Optional[torch.Tensor] = None,
) -> float:
    # TODO: 2 points -- Test model and return accuracy
    model.eval()
    true_preds, count = 0.0, 0

    for imgs, labels in tqdm(data_loader, desc="Testing"):
        imgs, labels = imgs.to(device), labels.to(device)
        shuffled_imgs = shuffle_pixels(imgs, shuffle_idx_shared)  # Apply pixel shuffling

        shuffled_imgs = shuffled_imgs.view(shuffled_imgs.size(0), -1)
        outputs = model(shuffled_imgs)
        true_preds += (outputs.argmax(dim=1) == labels).sum().item()
        count += labels.size(0)
        
    test_acc = true_preds / count
    return test_acc
    # raise NotImplementedError

# %%
def train_model_pixelshuffled(
    model,
    optimizer,
    loss_module,
    train_data_loader,
    val_data_loader,
    num_epochs=25,
    model_name="MyMLP_pixelshuffled",
    shuffle_idx_shared: Optional[torch.Tensor] = None,
):
    # Set model to train mode
    model.to(device)
    best_val_acc = -1.0

    # Training loop
    for epoch in range(1, num_epochs + 1):
        train_acc = train_one_epoch_pixelshuffled(model, optimizer, loss_module, train_data_loader, shuffle_idx_shared=shuffle_idx_shared)

        if epoch % 5 == 0 or epoch == num_epochs:
            # Evaluate the model and save if best
            acc = test_model_pixelshuffled(model, val_data_loader, shuffle_idx_shared=shuffle_idx_shared)
            if acc > best_val_acc:
                best_val_acc = acc
                save_model(model, model_name, CHECKPOINT_PATH)

            print(
                f"[Epoch {epoch+1:2d}] Training accuracy: {train_acc*100.0:05.2f}%, Validation accuracy: {acc*100.0:05.2f}%, Best validation accuracy: {best_val_acc*100.0:05.2f}%"
            )

    # Load best model after training
    model = load_model(model, model_name, CHECKPOINT_PATH)
    return model

# %%
# Create model, optimizer, and start training on fixed shuffling of pixels
model_mlp_pixelshuffled_shared = MLP(act_layer=nn.ReLU).to(device)
optimizer = SGDMomentum(model_mlp_pixelshuffled_shared.parameters(), lr=0.1)
loss_module = nn.CrossEntropyLoss().to(device)

# TODO: 2 points -- Create a shared: shuffle_idx
H, W = 32, 32 
shuffle_idx = torch.randperm(H * W, device=device)
# raise NotImplementedError

model_mlp_pixelshuffled_shared = train_model_pixelshuffled(
    model_mlp_pixelshuffled_shared,
    optimizer,
    loss_module,
    train_loader,
    val_loader,
    num_epochs=5,
    model_name="myMLP_ReLU_pixelshuffled_shared",
    shuffle_idx_shared=shuffle_idx,
)
# Out:
# Testing:   0%|          | 0/40 [00:00<?, ?it/s]
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_pixelshuffled_shared.pt
# [Epoch  6] Training accuracy: 57.31%, Validation accuracy: 53.20%, Best validation accuracy: 53.20%
# Model loaded from ../checkpoints/ece763_proj_01\myMLP_ReLU_pixelshuffled_shared.pt

# %%
# Create model, optimizer, and start training on a new shuffling of pixels per batch/image
model_mlp_pixelshuffled_batch = MLP(act_layer=nn.ReLU).to(device)
optimizer = SGDMomentum(model_mlp_pixelshuffled_batch.parameters(), lr=0.1)
loss_module = nn.CrossEntropyLoss().to(device)

model_mlp_pixelshuffled_batch = train_model_pixelshuffled(
    model_mlp_pixelshuffled_batch,
    optimizer,
    loss_module,
    train_loader,
    val_loader,
    num_epochs=5,
    model_name="myMLP_ReLU_pixelshuffled_batch",
    shuffle_idx_shared=None,
)
# Out:
# Testing:   0%|          | 0/40 [00:00<?, ?it/s]
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_pixelshuffled_batch.pt
# [Epoch  6] Training accuracy: 25.84%, Validation accuracy: 27.60%, Best validation accuracy: 27.60%
# Model loaded from ../checkpoints/ece763_proj_01\myMLP_ReLU_pixelshuffled_batch.pt

# %% [markdown]
# What results do you observe? What does this tell us about the MLP being aware of the image structure? Add your results and observations below.
#
# * TODO: 2 points -- write down your observations
#
# The model achieves moderate accuracy (~50%) on shared shuffled pixels.
# This suggests that the MLP is learning relationships between shuffled pixel positions over time.
# However, this accuracy is lower than an MLP trained on unshuffled images, meaning MLP is sensitive to pixel order.
#
# The accuracy drops significantly (~25%) on batch shuffled pixels.
# This shows that when pixels are shuffled differently every time, the MLP cannot establish stable feature relationships.
# The model fails because pixel positions lose their semantic meaning, making learning impossible.

# %% [markdown]
# ## Part 3: Implementing the ConvNet
#
# We will repeat the experiments in Part 2, but with a ConvNet.

# %%
# ConvNet requires 4D image as input
def train_one_epoch(model: nn.Module, optimizer: OptimizerTemplate, loss_module, data_loader)->Tuple[float, int]:
    true_preds, count = 0.0, 0
    model.train()
    for imgs, labels in data_loader:
        imgs, labels = imgs.to(device), labels.to(device) 
        
        optimizer.zero_grad() 
        outputs = model(imgs) 
        loss = loss_module(outputs, labels) 

        loss.backward() 
        optimizer.step()  

        # Compute predictions
        preds = outputs.argmax(dim=1) 
        true_preds += (preds == labels).sum().item()  
        count += labels.size(0)  
       
        # Record statistics during training
        
    train_acc = true_preds / count
    return train_acc

# %%
# ConvNet requires 4D image as input
@torch.no_grad()
def test_model(model, data_loader):
    model.eval() 
    true_preds, count = 0.0, 0

    for imgs, labels in data_loader:
        imgs, labels = imgs.to(device), labels.to(device) 

        outputs = model(imgs) 
        preds = outputs.argmax(dim=1) 

        true_preds += (preds == labels).sum().item() 
        count += labels.size(0)  

    accuracy = true_preds / count  
    return accuracy
    # raise NotImplementedError

# %% [markdown]
# ### Part 3.1: Vanilla ConvNet
#
# Let's start with a simple LeNet like ConvNet, consisting of a number of convolution blocks (e.g., two Conv+ReLU+MaxPool blocks) followed by a MLP consisting of two hidden layers.

# %%
class ConvNet(nn.Module):
    def __init__(self, in_chans: int=3, base_dims: int=32, num_classes:int=10, act_layer=nn.ReLU)->None:
        super().__init__()
        # TODO: 2 points -- write code for two Conv+ReLU+MaxPool blocks
        # First Conv Block: Conv + ReLU + MaxPool
        self.conv = nn.Sequential(
            nn.Conv2d(in_chans, base_dims, kernel_size=1, stride=1, padding=1),
            act_layer(),
            nn.MaxPool2d(kernel_size=2, stride=2),  # Reduce spatial size by half
            nn.Conv2d(base_dims, base_dims * 2, kernel_size=1, stride=1, padding=1),
            act_layer(),
            nn.MaxPool2d(kernel_size=2, stride=2)  # Reduce spatial size by half again
        )
        # raise NotImplementedError
        

        self.mlp = MLP(input_dim=base_dims*2, num_classes=num_classes, hidden_dims=[base_dims*4, base_dims*2], act_layer=act_layer)

    def forward(self, x):
        x = self.conv(x)
        x = x.mean(dim=(2, 3))
        x = self.mlp(x)
        return x

# %%
# Create model, optimizer, and start training

model_convnet = ConvNet(act_layer=nn.ReLU).to(device)
optimizer = SGDMomentum(model_convnet.parameters(), lr=0.1)
loss_module = nn.CrossEntropyLoss().to(device)

print(f"model convnet created: {count_parameters(model_convnet):05.3f}M")
model_convnet = train_model(
    model_convnet,
    optimizer,
    loss_module,
    train_loader,
    val_loader,
    num_epochs=5,
    model_name="myConvNet_ReLU",
)
# Out:
# model convnet created: 0.020M
# Model saved to ../checkpoints/ece763_proj_01\myConvNet_ReLU.pt
# [Epoch  6] Training accuracy: 38.84%, Validation accuracy: 41.90%, Best validation accuracy: 41.90%
# Model loaded from ../checkpoints/ece763_proj_01\myConvNet_ReLU.pt

# %%
# Test best model on test set
vanilla_convnet_test_acc = test_model(model_convnet, test_loader)
print(f"Test accuracy: {vanilla_convnet_test_acc*100.0:05.2f}%")
# Out:
# Test accuracy: 40.71%

# %% [markdown]
# You will observe accuracy around $\sim41-43\%$, worse than the vanilla MLP. Next, we will try to address the performance issue by modifying the specifications of ConvNets.

# %% [markdown]
# ### Part 3.2: Improving the ConvNet

# %% [markdown]
# Similar to Part 2.2. Please explore how to redesign your ConvNet to improve the performance.

# %%
# TODO: 10 points -- Improve the model and list the changes as code comments.
# You may try different changes (e.g. those suggested in Part 2.2) individually or combine them.
# You do not need to explore all the four suggestions above.
# You can create as many code blocks as you need.

# Add additional layers (Batch Normalization, LeakReLU and Dropout) and increase kernel size
class ConvNet(nn.Module):
    def __init__(self, in_chans: int=3, base_dims: int=32, num_classes:int=10, act_layer=nn.ReLU)->None:
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_chans, base_dims, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(base_dims),  # Batch Norm
            act_layer() if act_layer != nn.LeakyReLU else nn.LeakyReLU(negative_slope=0.01),  # LeakyReLU
            nn.Conv2d(base_dims, base_dims * 2, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(base_dims * 2),  # Batch Norm
            act_layer() if act_layer != nn.LeakyReLU else nn.LeakyReLU(negative_slope=0.01),  # LeakyReLU
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.2)  # Dropout
        )

        self.mlp = MLP(input_dim=base_dims*2, num_classes=num_classes, hidden_dims=[base_dims*4, base_dims*2], act_layer=act_layer)

    def forward(self, x):
        x = self.conv(x)
        x = x.mean(dim=(2, 3))
        x = self.mlp(x)
        return x
# raise NotImplementedError

# %%
# Reduce learning rate and add more epochs
model_convnet_improved = ConvNet(act_layer=nn.ReLU).to(device)
optimizer = SGDMomentum(model_convnet_improved.parameters(), lr=0.05)
loss_module = nn.CrossEntropyLoss().to(device)

print(f"model convnet created: {count_parameters(model_convnet_improved):05.3f}M")
model_convnet_improved = train_model(
    model_convnet_improved,
    optimizer,
    loss_module,
    train_loader,
    val_loader,
    num_epochs=15,
    model_name="myConvNet_ReLU_Improved",
)

convnet_improved_test_acc = test_model(model_convnet_improved, test_loader)
print(f"Test accuracy: {convnet_improved_test_acc*100.0:05.2f}%")
# Out:
# model convnet created: 0.037M
# Model saved to ../checkpoints/ece763_proj_01\myConvNet_ReLU_Improved.pt
# [Epoch  6] Training accuracy: 43.95%, Validation accuracy: 46.86%, Best validation accuracy: 46.86%
# Model saved to ../checkpoints/ece763_proj_01\myConvNet_ReLU_Improved.pt
# [Epoch 11] Training accuracy: 52.42%, Validation accuracy: 51.36%, Best validation accuracy: 51.36%
# Model saved to ../checkpoints/ece763_proj_01\myConvNet_ReLU_Improved.pt
# [Epoch 16] Training accuracy: 56.26%, Validation accuracy: 58.32%, Best validation accuracy: 58.32%
# Model loaded from ../checkpoints/ece763_proj_01\myConvNet_ReLU_Improved.pt
# Test accuracy: 56.10%

# %% [markdown]
# ### Part 3.3: Testing if ConvNets can address the limitations of MLP

# %% [markdown]
# Similar to Part 2.3. Test your improved ConvNet to compare the results with those in Part 2.3.

# %%
def train_one_epoch_pixelshuffled(
    model: nn.Module,
    optimizer: OptimizerTemplate,
    loss_module,
    data_loader,
    shuffle_idx_shared: Optional[torch.Tensor] = None,
) -> Tuple[float, int]:
    true_preds, count = 0.0, 0
    model.train()
    for imgs, labels in data_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        shuffled_imgs = shuffle_pixels(imgs, shuffle_idx_shared)

        optimizer.zero_grad()
        outputs = model(shuffled_imgs)
        loss = loss_module(outputs, labels)
        loss.backward()
        optimizer.step()

        true_preds += (outputs.argmax(dim=1) == labels).sum().item()
        count += labels.size(0)
        # Record statistics during training
    train_acc = (true_preds / count) if count > 0 else 0.0
    return train_acc

# %%
@torch.no_grad()
def test_model_pixelshuffled(
    model: nn.Module,
    data_loader,
    shuffle_idx_shared: Optional[torch.Tensor] = None,
) -> float:
    model.eval()
    true_preds, count = 0.0, 0

    for imgs, labels in tqdm(data_loader, desc="Testing"):
        imgs, labels = imgs.to(device), labels.to(device)
        shuffled_imgs = shuffle_pixels(imgs, shuffle_idx_shared)  # Apply pixel shuffling

        outputs = model(shuffled_imgs)
        true_preds += (outputs.argmax(dim=1) == labels).sum().item()
        count += labels.size(0)
        
    test_acc = true_preds / count
    return test_acc

# %%
# TODO: 2 points -- Train your best ConvNet using data with a shared pixel shuffle and check the accuracy for training, validation and testing datasets
model_conv_pixelshuffled_shared = ConvNet(act_layer=nn.ReLU).to(device)
optimizer = SGDMomentum(model_conv_pixelshuffled_shared.parameters(), lr=0.1)
loss_module = nn.CrossEntropyLoss().to(device)

H, W = 32, 32 
shuffle_idx = torch.randperm(H * W, device=device)

model_conv_pixelshuffled_shared = train_model_pixelshuffled(
    model_conv_pixelshuffled_shared,
    optimizer,
    loss_module,
    train_loader,
    val_loader,
    num_epochs=15,
    model_name="myConvNet_ReLU_pixelshuffled_shared",
    shuffle_idx_shared=shuffle_idx,
)
# Out:
# Testing:   0%|          | 0/40 [00:00<?, ?it/s]
# Model saved to ../checkpoints/ece763_proj_01\myConvNet_ReLU_pixelshuffled_shared.pt
# [Epoch  6] Training accuracy: 33.04%, Validation accuracy: 33.18%, Best validation accuracy: 33.18%
# Testing:   0%|          | 0/40 [00:00<?, ?it/s]
# Model saved to ../checkpoints/ece763_proj_01\myConvNet_ReLU_pixelshuffled_shared.pt
# [Epoch 11] Training accuracy: 37.88%, Validation accuracy: 38.52%, Best validation accuracy: 38.52%
# Testing:   0%|          | 0/40 [00:00<?, ?it/s]
# Model saved to ../checkpoints/ece763_proj_01\myConvNet_ReLU_pixelshuffled_shared.pt
# [Epoch 16] Training accuracy: 40.77%, Validation accuracy: 42.98%, Best validation accuracy: 42.98%
# Model loaded from ../checkpoints/ece763_proj_01\myConvNet_ReLU_pixelshuffled_shared.pt

# %%
# TODO: 2 points -- Train your best ConvNet using data with a per-batch pixel shuffle and check the accuracy for training, validation and testing datasets pixel shuffle and check the accuracy for training, validation and testing datasets
model_conv_pixelshuffled_batch = ConvNet(act_layer=nn.ReLU).to(device)
optimizer = SGDMomentum(model_conv_pixelshuffled_batch.parameters(), lr=0.1)
loss_module = nn.CrossEntropyLoss().to(device)

model_conv_pixelshuffled_batch = train_model_pixelshuffled(
    model_conv_pixelshuffled_batch,
    optimizer,
    loss_module,
    train_loader,
    val_loader,
    num_epochs=15,
    model_name="myConvNet_ReLU_pixelshuffled_batch",
    shuffle_idx_shared=None,
)
# Out:
# Testing:   0%|          | 0/40 [00:00<?, ?it/s]
# Model saved to ../checkpoints/ece763_proj_01\myConvNet_ReLU_pixelshuffled_batch.pt
# [Epoch  6] Training accuracy: 32.22%, Validation accuracy: 32.56%, Best validation accuracy: 32.56%
# Testing:   0%|          | 0/40 [00:00<?, ?it/s]
# Model saved to ../checkpoints/ece763_proj_01\myConvNet_ReLU_pixelshuffled_batch.pt
# [Epoch 11] Training accuracy: 35.88%, Validation accuracy: 36.62%, Best validation accuracy: 36.62%
# Testing:   0%|          | 0/40 [00:00<?, ?it/s]
# Model saved to ../checkpoints/ece763_proj_01\myConvNet_ReLU_pixelshuffled_batch.pt
# [Epoch 16] Training accuracy: 38.44%, Validation accuracy: 39.20%, Best validation accuracy: 39.20%
# Model loaded from ../checkpoints/ece763_proj_01\myConvNet_ReLU_pixelshuffled_batch.pt

# %% [markdown]
# ## Part 4: Fitting noisy
#
# We will re-create a training dataset with ground-truth labels shuffled (i.e., labels become noisys). Then, we train our MLPs and ConvNets to check the training accuracy. If they could do a good job, it means that there are potential risks of fitting noisys of deep neural networks, and we shall be careful in monitoring the data quality in supervised training.

# %% [markdown]
# ### Shuffle the Ground-Truth Labels

# %%
# TODO: 2 points -- Create a training dataset with ground-truth labels shuffled
from PIL import Image
# Load original training dataset
original_train_dataset = train_loader.dataset.dataset 

# Extract images and labels
imgs, labels = original_train_dataset.data, original_train_dataset.targets

# Convert labels to PyTorch tensor
labels = torch.tensor(labels, dtype=torch.long)

# Apply transformations
resize_transform = transforms.Compose([
    transforms.Resize((32, 32)),  # Ensure correct size
    transforms.ToTensor(),  # Convert to tensor AFTER augmentation
    transforms.Normalize(DATA_MEANS, DATA_STD)  # Normalize images
])

# Convert each image to PIL format, apply transformations, and convert back to tensor
imgs_resized = torch.stack([resize_transform(Image.fromarray(img)) for img in imgs])

# Shuffle labels 
shuffled_labels = labels[torch.randperm(len(labels))]

noise_train_dataset = torch.utils.data.TensorDataset(imgs_resized, shuffled_labels)

# Create data loaders for later
noise_train_loader = data.DataLoader(
    noise_train_dataset,
    batch_size=128,
    shuffle=True,
    drop_last=True,
    pin_memory=True,
    num_workers=3,
)

# %% [markdown]
# ### Verify labels are shuffled

# %%
noise_dataiter = iter(noise_train_loader)
noise_images, noisey_labels = next(noise_dataiter)

# %%
imshow(torchvision.utils.make_grid(noise_images))
for i in range(0, len(noisey_labels), 8):
    print(
        f"Noisy labels (row {i//8}): ",
        " ".join(f"{classes[noisey_labels[i+j]]:5s}" for j in range(8)),
    )
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# Noisy labels (row 0):  car   cat   cat   cat   ship  deer  dog   bird
# Noisy labels (row 1):  dog   cat   dog   cat   plane horse truck plane
# Noisy labels (row 2):  ship  cat   frog  bird  frog  frog  car   car
# Noisy labels (row 3):  ship  horse ship  plane dog   dog   plane frog
# Noisy labels (row 4):  cat   horse car   car   deer  ship  frog  truck
# Noisy labels (row 5):  frog  ship  horse plane cat   deer  horse plane
# Noisy labels (row 6):  horse horse ship  plane horse bird  horse bird
# Noisy labels (row 7):  ship  frog  ship  car   bird  car   horse bird
# Noisy labels (row 8):  car   bird  car   dog   frog  dog   cat   cat
# Noisy labels (row 9):  bird  plane cat   dog   horse bird  horse frog
# Noisy labels (row 10):  bird  bird  plane bird  horse bird  cat   car
# Noisy labels (row 11):  dog   cat   frog  dog   truck car   dog   frog
# Noisy labels (row 12):  car   car   bird  bird  frog  plane ship  deer
# Noisy labels (row 13):  deer  car   plane dog   dog   horse plane plane
# Noisy labels (row 14):  bird  cat   plane bird  ship  truck bird  plane
# Noisy labels (row 15):  car   dog   car   dog   truck truck dog   deer

# %%
class MLP(nn.Module):

    def __init__(self, input_dim: int=3072, num_classes: int=10, hidden_dims: List[int]=[256, 128], act_layer: nn.Module=nn.ReLU)->None:
        """
        Inputs:
            input_dim - Dimension of the input images in pixels
            num_classes - Number of classes we want to predict. The output size of the MLP
                          should be num_classes.
            hidden_dims - A list of integers specifying the hidden layer dimensions in the MLP. 
                           The MLP should have len(hidden_sizes)+1 linear layers.
            act_layer - Activation function.
        """
        super().__init__()
        layers = []
        in_dim = input_dim
        
        # Creating hidden layers
        for hidden_dim in hidden_dims:
            layers.append(nn.Linear(in_dim, hidden_dim))
            # layers.append(act_layer())
            layers.append(nn.BatchNorm1d(hidden_dim))  # Batch Normalization
            if act_layer == nn.LeakyReLU:
                layers.append(act_layer(negative_slope=0.01))  # LeakyReLU needs negative_slope
            else:
                layers.append(act_layer())  # Other activations don't need arguments
            layers.append(nn.Dropout(0.2))  # Dropout layer
            in_dim = hidden_dim
        
        # Output layer
        layers.append(nn.Linear(in_dim, num_classes))
        
        self.model = nn.Sequential(*layers)
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.model(x)

# %%
def train_one_epoch(model: nn.Module, optimizer: OptimizerTemplate, loss_module, data_loader)->Tuple[float, int]:
    true_preds, count = 0.0, 0
    model.train()
    for imgs, labels in data_loader:
        imgs, labels = imgs.to(device), labels.to(device)
        
        optimizer.zero_grad() 
        imgs = imgs.view(imgs.size(0), -1)  
        outputs = model(imgs)  
        
        loss = loss_module(outputs, labels) 
        
        loss.backward() 
        optimizer.step()  

        preds = outputs.argmax(dim=1)  
        true_preds += (preds == labels).sum().item()  
        count += labels.size(0) 
       
        # Record statistics during training
        
    train_acc = true_preds / count
    return train_acc

# %%
@torch.no_grad()
def test_model(model, data_loader):
    model.eval()  
    true_preds, count = 0.0, 0

    for imgs, labels in data_loader:
        imgs, labels = imgs.to(device), labels.to(device)  

        imgs = imgs.view(imgs.size(0), -1) 
        outputs = model(imgs)  
        preds = outputs.argmax(dim=1) 

        true_preds += (preds == labels).sum().item()  
        count += labels.size(0) 

    accuracy = true_preds / count  
    return accuracy

# %% [markdown]
# ### Training MLPs and ConvNets on the noisy datasets

# %%
# TODO: 5 points -- Train your best MLP and check the training accuracy
model_mlp_noisy = MLP(act_layer=nn.ReLU).to(device)
optimizer = SGDMomentum(model_mlp_noisy.parameters(), lr=0.05) # you may tune lr
loss_module = nn.CrossEntropyLoss().to(device)

print(f'model mlp created: {count_parameters(model_mlp_noisy):05.3f}M')
model_mlp_noisy=train_model(
    model_mlp_noisy, 
    optimizer, 
    loss_module, 
    noise_train_loader, 
    val_loader, 
    num_epochs=5, 
    model_name="myMLP_ReLU_Noisy")

mlp_noisy_test_acc = test_model(model_mlp_noisy, test_loader)
print(f'Test accuracy: {mlp_noisy_test_acc*100.0:05.2f}%')
# Out:
# model mlp created: 0.822M
# Model saved to ../checkpoints/ece763_proj_01\myMLP_ReLU_Noisy.pt
# [Epoch  6] Training accuracy: 12.08%, Validation accuracy: 10.96%, Best validation accuracy: 10.96%
# Model loaded from ../checkpoints/ece763_proj_01\myMLP_ReLU_Noisy.pt
# Test accuracy: 10.55%

# %%
class ConvNet(nn.Module):
    def __init__(self, in_chans: int=3, base_dims: int=32, num_classes:int=10, act_layer=nn.ReLU)->None:
        super().__init__()
        # First Conv Block: Conv + ReLU + MaxPool
        self.conv = nn.Sequential(
            nn.Conv2d(in_chans, base_dims, kernel_size=5, stride=1, padding=1),
            nn.BatchNorm2d(base_dims),  # Batch Norm
            act_layer() if act_layer != nn.LeakyReLU else nn.LeakyReLU(negative_slope=0.01),  # LeakyReLU
            nn.Conv2d(base_dims, base_dims * 2, kernel_size=5, stride=1, padding=1),
            nn.BatchNorm2d(base_dims * 2),  # Batch Norm
            act_layer() if act_layer != nn.LeakyReLU else nn.LeakyReLU(negative_slope=0.01),  # LeakyReLU
            nn.MaxPool2d(kernel_size=5, stride=2),
            nn.Dropout(0.5)  # Dropout
        )
        

        self.mlp = MLP(input_dim=base_dims*2, num_classes=num_classes, hidden_dims=[base_dims*4, base_dims*2], act_layer=act_layer)

    def forward(self, x):
        x = self.conv(x)
        x = x.mean(dim=(2, 3))
        x = self.mlp(x)
        return x

# %%
# ConvNet requires 4D image as input
def train_one_epoch(model: nn.Module, optimizer: OptimizerTemplate, loss_module, data_loader)->Tuple[float, int]:
    true_preds, count = 0.0, 0
    model.train()
    for imgs, labels in data_loader:
        imgs, labels = imgs.to(device), labels.to(device)  
        
        optimizer.zero_grad()  
        outputs = model(imgs)  
        
        loss = loss_module(outputs, labels) 
        
        loss.backward() 
        optimizer.step() 

        # Compute predictions
        preds = outputs.argmax(dim=1) 
        true_preds += (preds == labels).sum().item() 
        count += labels.size(0)  
       
        # Record statistics during training
        
    train_acc = true_preds / count
    return train_acc

# %%
# ConvNet requires 4D image as input
@torch.no_grad()
def test_model(model, data_loader):
    model.eval()  
    true_preds, count = 0.0, 0

    for imgs, labels in data_loader:
        imgs, labels = imgs.to(device), labels.to(device)  

        outputs = model(imgs) 
        preds = outputs.argmax(dim=1)  

        true_preds += (preds == labels).sum().item()  
        count += labels.size(0)  

    accuracy = true_preds / count 
    return accuracy

# %%
# TODO: 5 points -- Train your best ConvNet and check the training accuracy
model_convnet_noisy = ConvNet(act_layer=nn.ReLU).to(device)
optimizer = SGDMomentum(model_convnet_noisy.parameters(), lr=0.05) # you may tune lr
loss_module = nn.CrossEntropyLoss().to(device)

print(f'model convnet created: {count_parameters(model_convnet_noisy):05.3f}M')
model_convnet_noisy=train_model(
    model_convnet_noisy, 
    optimizer, 
    loss_module, 
    noise_train_loader, 
    val_loader, 
    num_epochs=5, 
    model_name="myConvNet_ReLU_Noisy")

convnet_noisy_test_acc = test_model(model_convnet_noisy, test_loader)
print(f'Test accuracy: {convnet_noisy_test_acc*100.0:05.2f}%')
# Out:
# model convnet created: 0.071M
# Model saved to ../checkpoints/ece763_proj_01\myConvNet_ReLU_Noisy.pt
# [Epoch  6] Training accuracy: 10.10%, Validation accuracy: 07.94%, Best validation accuracy: 07.94%
# Model loaded from ../checkpoints/ece763_proj_01\myConvNet_ReLU_Noisy.pt
# Test accuracy: 08.16%

# %% [markdown]
# ## Conclusion
#
# You have reached the end of the practical, congratulations! Now, you should have a good idea of what it means to train a MLP, how we can use neural networks to perform image classification, what aspects there are to improve a networks performance, and what limitations and risks there are.
